# %%
# !g++ caue.cpp -o caue && ./caue
# Out:
# TC1 Input(5,3,1) -> Output: 5
# TC2 Input(5,5,3) -> Output: 0
# TC3 Input(7,7,7) -> Output: 0
# TC4 Input(-1,-2,-3) -> Output: -1
# TC5 Input(2,9,4) -> Output: 9
# TC6 Input(3,6,10) -> Output: 10

# %% [markdown]
# #### Phân tích số lượng test-cases cần thiết
#
# Biến max được khởi tạo = 0, dẫn đến kết quả sai nếu tất cả điều kiện if không thỏa mãn (ví dụ: các số bằng nhau, hoặc toàn số âm).
#
# Hàm chỉ so sánh với toán tử > mà không xét >=, nên trường hợp các số bằng nhau không được xử lý.
#
# Kết quả sai đặc biệt ở:
#
# Số âm: có thể trả về 0 thay vì số âm lớn nhất.
#
# Các số bằng nhau: trả về 0 thay vì giá trị đúng.
#
# Kiểm tra tính đúng đắn của hàm findMax trong các trường hợp:
#
# Khi num1 là số lớn nhất.
#
# Khi num2 là số lớn nhất.
#
# Khi num3 là số lớn nhất.
#
# Khi toàn bộ là số âm.
#
# Khi cả ba số bằng nhau.
#
# | **Test Case** | **Input (num1,num2,num3)** | **Expected Output** | **Kết quả chạy** | **Đánh giá** |
# | ------------- | -------------------------- | ------------------- | ---------------- | ------------ |
# | **TC1**       | (5, 3, 1)                  | 5                   | 5                | PASS         |
# | **TC2**       | (5, 5, 3)                  | 5                   | 0                | FAIL         |
# | **TC3**       | (7, 7, 7)                  | 7                   | 0                | FAIL         |
# | **TC4**       | (-1, -2, -3)               | -1                  | -1               | PASS         |
# | **TC5**       | (2, 9, 4)                  | 9                   | 9                | PASS         |
# | **TC6**       | (3, 6, 10)                 | 10                  | 10               | PASS         |
#
# Các test case TC1, TC4, TC5, TC6 chạy đúng.
#
# Các test case TC2 và TC3 thất bại → đã phát hiện ra lỗi logic trong hàm.
#
# **Kết luận**
#
# Để kiểm thử toàn diện hàm findMax, cần ít nhất 5 test case (bao gồm các tình huống lớn nhất ở num1, num2, num3, toàn số âm, các số bằng nhau).
#
# Bộ test hiện tại (6 test case) đã bao phủ đầy đủ và phát hiện lỗi.
#
# Hàm findMax cần được sửa lại để xử lý đúng các trường hợp bằng nhau và số âm
