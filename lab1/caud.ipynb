# %%
# Biên dịch C++ code
# !g++ caud.cpp -o caud

# Chạy chương trình, đọc input từ input.txt, ghi kết quả ra output.txt
# !./caud < input.txt > output.txt

# Hiển thị nội dung file output
# !cat output.txt
# Out:
# f3(8) = 16
# f3(12) = 24
# f3(10) = 20
# f3(0) = 0
# f3(-5) = -10

# %% [markdown]
# #### Phân tích số lượng test-case cần thiết
#
# Cả nhánh if và else đều trả về cùng một kết quả: 2 * x.
#
# Vì vậy, về mặt kết quả thì bất kỳ input hợp lệ nào cũng ra 2 * x.
#
# Tuy nhiên, để kiểm thử đầy đủ, ta phải xét các trường hợp đặc biệt của biểu thức log(x * x * cos(x)).
#
# | **Test Case** | **Input (x)** | **Expected Output** | **Actual Output** | **Kết quả** |
# | ------------- | ------------- | ------------------- | ----------------- | ----------- |
# | TC1           | 8             | 16                  | 16                | PASS      |
# | TC2           | 12            | 24                  | 24                | PASS    |
# | TC3           | 10            | 20                  | 20                | PASS     |
# | TC4           | 0             | 0                   | 0                 | PASS      |
# | TC5           | -5            | -10                 | -10               | PASS     |
#
#
# Trong trường hợp này tất cả test đều PASS vì chương trình cho ra đúng kết quả như mong đợi (dù về mặt toán học log(âm) hay log(0) không xác định, nhưng C++ vẫn xử lý thành NaN hoặc -inf và chương trình vẫn chạy).
#
# **Kết luận**
#
# Số lượng test-case cần thiết: 5.
#
# Các test-case: x = 8, 12, 10, 0, -5.
#
# Bộ test bao phủ được:
#
# Trường hợp hợp lệ (x²·cos(x) > 0)
#
# Trường hợp log(0) = -inf
#
# Trường hợp log(âm) = NaN
#
# Chương trình hoạt động ổn định, không phát sinh lỗi runtime, và cho kết quả thống nhất với logic cài đặt hiện tại.
